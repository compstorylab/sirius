# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import libraries</a></span><ul class="toc-item"><li><span><a href="#Data-processing" data-toc-modified-id="Data-processing-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Data processing</a></span></li><li><span><a href="#Visualization" data-toc-modified-id="Visualization-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Visualization</a></span></li></ul></li><li><span><a href="#Parameter-settings" data-toc-modified-id="Parameter-settings-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Parameter settings</a></span></li><li><span><a href="#Import-Data" data-toc-modified-id="Import-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Import Data</a></span></li></ul></li><li><span><a href="#Helper-functions" data-toc-modified-id="Helper-functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Helper functions</a></span><ul class="toc-item"><li><span><a href="#Identify-feature-type" data-toc-modified-id="Identify-feature-type-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Identify feature type</a></span></li><li><span><a href="#Data-structures" data-toc-modified-id="Data-structures-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data structures</a></span></li></ul></li><li><span><a href="#Main-Functions" data-toc-modified-id="Main-Functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Main Functions</a></span><ul class="toc-item"><li><span><a href="#Visualization" data-toc-modified-id="Visualization-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visualization</a></span><ul class="toc-item"><li><span><a href="#Discrete-Discrete-Confusion-Matrices" data-toc-modified-id="Discrete-Discrete-Confusion-Matrices-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Discrete-Discrete Confusion Matrices</a></span></li><li><span><a href="#Discrete-Continuous-Violin-Plots" data-toc-modified-id="Discrete-Continuous-Violin-Plots-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Discrete-Continuous Violin Plots</a></span></li><li><span><a href="#Continuous-Continuous-KDE-Plots" data-toc-modified-id="Continuous-Continuous-KDE-Plots-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Continuous-Continuous KDE Plots</a></span></li><li><span><a href="#Matrix-Heatmap" data-toc-modified-id="Matrix-Heatmap-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Matrix Heatmap</a></span></li><li><span><a href="#Visualization-Function-Router" data-toc-modified-id="Visualization-Function-Router-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Visualization Function Router</a></span></li></ul></li><li><span><a href="#Mutual-Information" data-toc-modified-id="Mutual-Information-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Mutual Information</a></span><ul class="toc-item"><li><span><a href="#Discrete-Discrete" data-toc-modified-id="Discrete-Discrete-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Discrete-Discrete</a></span></li><li><span><a href="#Discrete-Continuous" data-toc-modified-id="Discrete-Continuous-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Discrete-Continuous</a></span></li><li><span><a href="#Continuous-Continuous" data-toc-modified-id="Continuous-Continuous-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Continuous-Continuous</a></span><ul class="toc-item"><li><span><a href="#Comparison:-Correlation" data-toc-modified-id="Comparison:-Correlation-3.2.3.1"><span class="toc-item-num">3.2.3.1&nbsp;&nbsp;</span>Comparison: Correlation</a></span></li></ul></li></ul></li><li><span><a href="#Matrix-Functions" data-toc-modified-id="Matrix-Functions-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Matrix Functions</a></span></li><li><span><a href="#Data-Processing" data-toc-modified-id="Data-Processing-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Data Processing</a></span></li></ul></li><li><span><a href="#Calculation" data-toc-modified-id="Calculation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Calculation</a></span></li><li><span><a href="#Network-Graphing" data-toc-modified-id="Network-Graphing-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Network Graphing</a></span><ul class="toc-item"><li><span><a href="#Thresholding" data-toc-modified-id="Thresholding-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Thresholding</a></span></li><li><span><a href="#Node-and-Edge-Lists" data-toc-modified-id="Node-and-Edge-Lists-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Node and Edge Lists</a></span></li><li><span><a href="#Positioning" data-toc-modified-id="Positioning-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Positioning</a></span></li><li><span><a href="#Draw-Graph" data-toc-modified-id="Draw-Graph-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Draw Graph</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Setup
# ## Import libraries
# ### Data processing

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import math
import random
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.metrics import normalized_mutual_info_score
from scipy.stats import multivariate_normal, pearsonr
import scipy.integrate as integrate
from sklearn.neighbors import KernelDensity
from pathlib import Path
import networkx as nx
import json

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

#Seaborn
import seaborn as sns
sns.set_style("whitegrid")

#Plotly
import plotly
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from plotly.colors import n_colors

# If you're using this code locally:
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# If you're copying this into a jupyter notebook, add:
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Parameter settings

# %%
chart = False # boolean for whether to display images while running computation
debug = True # boolean for whether to print updates to the console while running
output = True # boolean for whether to output json and pngs to files
charter = 'Plotly' # also accepts 'Seaborn'
#charter = 'Seaborn'
resolution = 150 # int for resolution of output plots
discrete_threshold = 5 # number of responses below which numeric responses are considered discrete
compare_all = True # boolean; if comparing two lists of the same length, fill in list1 and list2 accordingly
#list1, list2 = [],[]
sample_n = 1000 # Work with all data (None), or just a sample?
cd = 'demo_widsdatathon2020/'

# %%
if output:
    Path(cd+'output/').mkdir(parents=True, exist_ok=True)
    Path(cd+'output/charts').mkdir(parents=True, exist_ok=True)
    Path(cd+'output/json').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import Data

# %%
if sample_n: df = pd.read_csv(cd+'data.csv').sample(sample_n)
else: df = pd.read_csv(cd+'data.csv')
ignore = []
for i in list(df.columns):
    try: np.ma.fix_invalid(df[i])
    except: pass
    if ('_id' in i):
        ignore.append(i)
df = df.drop(columns=ignore)
df = df.replace(np.nan, None)
df = df.replace('nan', None)
if debug: print(f'Loaded data from {cd} with {df.shape[0]} observations and {df.shape[1]} features')
# Out:
# Loaded data from demo_widsdatathon2020/ with 1000 observations and 182 features

# %% [markdown]
# # Helper functions
# ## Identify feature type

# %%
# Get a list of all response types
response_list = pd.DataFrame(columns=['responses','types'], index=list(df.columns))
response_list['responses']=[list(df[col].value_counts().index) for col in df.columns]

# Delete columns from the dataframe that only have one response
response_list['only_one_r'] = [(len(r)<2) for r in response_list['responses']]
only_one_r = list(response_list[response_list['only_one_r']==True].index)
df = df.drop(columns=only_one_r)
response_list = response_list.drop(index=only_one_r)

# %%
def get_types(U):
  types = {'floats':0,'strings':0,'nulls': 0}
  for i in response_list['responses'][U]:
    try:
      val = float(i)
      if math.isnan(val)==False:
        #print("Value",i," is a float")
        types['floats']+=1
      else:
        #print("Value",i," is null")
        types['nulls']+=1
    except ValueError:
      try:
        val = str(i)
        #print("Value",i,"is a string")
        types['strings']+=1
      except:
        print('Error: Unexpected value',i,'for feature',U)
  if ((types['floats']>0) & (types['strings']>0)):
    print('Column',U,'contains floats AND strings')
  return types

# %%
response_list['types']=[get_types(col) for col in df.columns]
response_list['string']=[t['strings']>0 for t in response_list['types']]
response_list['float']=[t['floats']>0 for t in response_list['types']]

# Classify features as discrete (fewer than {discrete_threshold} responses, or contains strings) or continuous (more than 15)
response_list['class']=['d' if ((len(r) < discrete_threshold) or (t['strings']>0)) else 'c' for r,t in zip(response_list['responses'],response_list['types'])]

# Store these groups in a list
discrete = list(response_list[response_list['class']=='d'].index)
continuous = list(response_list[response_list['class']=='c'].index)

if debug: print(f'Counted {len(discrete)} discrete features and {len(continuous)} features')
# Out:
# Counted 23 discrete features and 157 features

# %%
# Format the data as a string or a float
for i in list(response_list.index):
    V = []
    if (response_list['string'][i]==True) or (response_list['class'][i]=='d'):
        V=[str(v) for v in df[i]]
        df[i]=V
    elif response_list['float'][i]==True:
        V = df[i]
        V=[float(v) for v in df[i]]
        df[i]=V
    else: print('Error formatting column ',i)

# %% [markdown]
# ## Data structures

# %%
def sparsify(series):
  ''' For discrete values: takes a column name and returns a sparse matrix (0 or 1) with a column for each unique response '''
  m=pd.DataFrame(columns=list(series.unique()))
  for i in list(series.unique()):
    m[i]=[int(x==i) for x in series]
  return m

def compute_bandwidth(X):
  ''' Takes a column name and computes suggested gaussian bandwidth with the formula: 1.06*var(n^-0.2) '''
  var = np.var(df[X])
  n = len(df[X].notnull())
  b = 1.06*var*(n**(-0.2))
  return b

# %% [markdown]
# # Main Functions
# ## Visualization
# ### Discrete-Discrete Confusion Matrices

# %%
def DD_viz(df):
    
  ''' Takes a filtered dataframe of two discrete feature columns and generates a heatmap '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]

  i_range = list(df[U].unique())
  j_range = list(df[V].unique())
  s = pd.DataFrame(columns=i_range,index=j_range)
  for i in i_range:
    for j in j_range:
      s[i][j]=df[(df[U]==i) & (df[V]==j)].filter([U,V],axis=1).shape[0]
      mutual_support=s.sum().sum()
  s = s.astype(int)

  if charter=='Plotly':
    fig = ff.create_annotated_heatmap(
        s.values,
        x=[str(i) for i in i_range],
        y=[str(j) for j in j_range],
        colorscale = 'Blues'
    )
    fig.update_layout(
        xaxis_title = U.replace('_',' ').title(),
        yaxis_title = V.replace('_',' ').title(),
        plot_bgcolor="rgba(0, 0, 0, 0)", 
        paper_bgcolor="rgba(0, 0, 0, 0)",
    )
    if chart: fig.show()
        
    if output:
        fig.update_xaxes(tickcolor='white',tickfont=dict(color='white'))
        fig.update_yaxes(tickcolor='white',tickfont=dict(color='white'))
        fig.update_layout(font=dict(color="white"))
        with open(str(cd+'output/charts/'+U+'_'+V+'.json'), 'w') as outfile:
            json.dump(fig.to_json(), outfile)
        fig.write_image(str(cd+'output/charts/'+U+'_'+V+'.png'), scale=resolution//72)
        
  else:
    plt.clf()
    plt.figure(dpi=resolution)
    sns.heatmap(s, annot=True, cmap="Blues", cbar=False, linewidths=1)
    plt.xlabel(U.replace('_',' ').title())
    plt.ylabel(V.replace('_',' ').title()) 
    if output: plt.savefig(str(cd+'output/charts/'+U+'_'+V+'.png'), dpi=resolution)
    if chart: plt.show()

  plt.close('all')
  return

# %%
if debug:
    try:
        DD_viz(df.filter(random.sample(discrete,2)).dropna(how='any'))
        print(f'Created an example discrete-discrete plot, generated using {charter}')
    except: pass
# Out:
# Created an example discrete-discrete plot, generated using Plotly

# %% [markdown]
# ### Discrete-Continuous Violin Plots

# %%
def DC_viz(df):

  ''' Takes a subset dataframe of one continuous and one discrete feature and generates a Violin Plot '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]
  
  if (U in continuous):
    D = V
    C = U
  else:
    D = U
    C = V
    
  if charter=='Plotly':
    fig = go.Figure()
    for i in list(df[D].unique()):
        series = df[df[D]==i][C]
        fig.add_trace(go.Violin(x=series, name=str(i)))

    fig.update_traces(orientation='h', side='positive', width=3, points=False)
    fig.update_layout(xaxis_showgrid=False, xaxis_zeroline=False,
        xaxis_title = U.replace('_',' ').title(),
        yaxis_title = V.replace('_',' ').title(),
        plot_bgcolor="rgba(0, 0, 0, 0)", 
        paper_bgcolor="rgba(0, 0, 0, 0)",
        showlegend=False
    )
    if chart: fig.show()
        
    if output:
        fig.update_xaxes(tickcolor='white',tickfont=dict(color='white'))
        fig.update_yaxes(tickcolor='white',tickfont=dict(color='white'))
        fig.update_layout(font=dict(color="white"))
        with open(str(cd+'output/charts/'+U+'_'+V+'.json'), 'w') as outfile:
            json.dump(fig.to_json(), outfile)
        fig.write_image(str(cd+'output/charts/'+U+'_'+V+'.png'), scale=resolution//72)
    
  else:
      sns.violinplot(df[D], df[C])
      if (len(df[D]) < 500): sns.swarmplot(x=df[D], y=df[C], edgecolor="white", linewidth=1) # Only show a swarm plot if there are fewer than 500 data points
      plt.xlabel(D.replace('_',' ').title())
      plt.ylabel(C.replace('_',' ').title())
    
      if output: plt.savefig(str(cd+'output/charts/'+U+'_'+V+'.png'), dpi=resolution)
        
      if chart: plt.show()
        
  plt.close('all')

  return

# %%
if debug:
    try:
        DC_viz(df.filter([random.choice(discrete),random.choice(continuous)]).dropna(how='any'))
        print(f'Created an example discrete-continuous plot, generated using {charter}')
    except:
        pass
# Out:
# Created an example discrete-continuous plot, generated using Plotly

# %% [markdown]
# ### Continuous-Continuous KDE Plots

# %%
def CC_viz(df):

  ''' Takes two continuous feature names and generates a 2D Kernel Density Plot '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]

  if charter=='Plotly':
        
    fig = ff.create_2d_density(df[U], df[V], colorscale = px.colors.sequential.Blues_r , hist_color=(135/255, 206/255, 250/255), title='')
    fig.update_layout(xaxis_showgrid=False, xaxis_zeroline=False,
        xaxis_title = U.replace('_',' ').title(),
        yaxis_title = V.replace('_',' ').title(),
        plot_bgcolor="rgba(0, 0, 0, 0)", 
        paper_bgcolor="rgba(0, 0, 0, 0)",
        showlegend=False
    )
    if chart: fig.show()
        
    if output:
        fig.update_xaxes(tickcolor='white',tickfont=dict(color='white'))
        fig.update_yaxes(tickcolor='white',tickfont=dict(color='white'))
        fig.update_layout(font=dict(color="white"))
        with open(str(cd+'output/charts/'+U+'_'+V+'.json'), 'w') as outfile:
            json.dump(fig.to_json(), outfile)
        fig.write_image(str(cd+'output/charts/'+U+'_'+V+'.png'), scale=resolution//72)

  else:
    sns.kdeplot(df[U], df[V], color='blue',shade=True, alpha=0.3, shade_lowest=False)
    if (len(df[U]) < 500): sns.scatterplot(x=df[U], y=df[V], color='blue', alpha=0.5, linewidth=0) # Only show a scatter plot if there are fewer than 500 data points
    plt.xlabel(U.replace('_',' ').title())
    plt.ylabel(V.replace('_',' ').title())
    if output:
      plt.savefig(str(cd+'output/charts/'+U+'_'+V+'.png'), dpi=resolution)
    if chart: plt.show()

  plt.close('all')

  return

# %%
if debug:
    try:
        CC_viz(df.filter([random.choice(continuous),random.choice(continuous)]).dropna(how='any'))
        print(f'Created an example continuous-continuous plot, generated using {charter}')
    except:
        pass
# Out:
# Created an example continuous-continuous plot, generated using Plotly

# %% [markdown]
# ### Matrix Heatmap

# %%
def matrix_viz(matrix):
   plt.clf()
   plt.figure(dpi=70,figsize=(10,8))
   sns.heatmap(matrix.fillna(0))
   plt.show()
   return()

# %% [markdown]
# ### Visualization Function Router

# %%
def viz(U,V):

  ''' Generate a visualization based on feature types '''

  plt.clf()
  plt.figure(dpi=resolution)

  pairdf = df.filter([U,V]).dropna(how='any')
  
  # If both features are discrete:
  if ((U in discrete) and (V in discrete)):
    viz = DD_viz(pairdf)
  # If both features are continuous:
  elif ((U in continuous) and (V in continuous)):
    viz = CC_viz(pairdf)
  # If one feature is continuous and one feature is discrete:
  elif (((U in continuous) and (V in discrete)) or ((U in discrete) and (V in continuous))):
    viz = DC_viz(pairdf)
  else:
    viz = print('Error on features',U,'and',V)

  if output: pairdf.to_json(str(cd+'output/json/'+U+'_'+V+'.json'))
    
  return viz

# %% [markdown]
# ## Mutual Information

# %% [markdown]
# ### Discrete-Discrete

# %%
def DD_mi(df):

  ''' Takes two discrete feature names and calculates normalized mutual information (dividing mutual information by maximum possible) '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]

  if debug: print(f'Calculating discrete-discrete normalized MI for {U} and {V}')
  min_response_count = min(len(list(df[U].unique())),len(list(df[V].unique())))
  max_mi = np.log2(min_response_count)
  if U == V:
      mi = max_mi
  else:
      i_range = list(df[U].unique())
      j_range = list(df[V].unique())
      # We use 's' to denote a matrix of support for each i,j
      s = pd.DataFrame(columns=i_range,index=j_range)
      for i in i_range:
        for j in j_range:
          s[i][j]=df[(df[U]==i) & (df[V]==j)].filter([U,V],axis=1).shape[0]
          mutual_support=s.sum().sum()
      s = s.astype(int)
      pmi = s.copy()
      l = []
      # If these features are never both answered, or if either feature only has one possible response:
      if (mutual_support <= 0 or len(i_range)<=1 or len(j_range)<=1):
        # The whole pointwise mutual information matrix should be 0
        pmi.fillna(0,inplace=True)
      else:
        for i in i_range:
          for j in j_range:
            joint_support=s[i][j]
            joint_probability = joint_support/mutual_support
            marginal_probability_i=s.sum(axis=0)[i]/s.sum().sum()
            marginal_probability_j=s.sum(axis=1)[j]/s.sum().sum()
            if joint_probability !=0:
              pmi[i][j]=np.log2(joint_probability/(marginal_probability_i*marginal_probability_j))
              # Store all PMI (pointwise mutual information) in a list
              l.append(pmi[i][j]*joint_probability)
        # Sum the list of all pointwise mutual information
        mi = sum(l)
  if max_mi==0:
      nmi = 0
  else:
      nmi = mi/max_mi
  return nmi

# %%
# Test it out:
try: DD_mi(df.filter(random.sample(discrete,2)).dropna(how='any'))
except: print('Error calculating MI for two discrete features')
# Out:
# Calculating discrete-discrete normalized MI for hepatic_failure and apache_2_bodysystem

# %%
DD_mi(df.filter(random.sample(discrete,2)).dropna(how='any'))
# Out:
# Calculating discrete-discrete normalized MI for hospital_admit_source and ventilated_apache
# 0.0

# %% [markdown]
# ### Discrete-Continuous
#
# This uses SciKit's [mutual_info_regression](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_regression.html) which calculates mutual information using the nearest neighbor entropy approach described in [*B. C. Ross “Mutual Information between Discrete and Continuous Data Sets”. PLoS ONE 9(2), 2014.*](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0087357)
#
# This requires us to sparsify the discrete matrix by response

# %%
def DC_mi(df):

  ''' Takes a subset df of one discrete and one continuous feature and, using a sparsified matrix of the discrete responses, returns mutual information score '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]

  if debug: print(f'Calculating discrete-continious MI for {U} and {V}')
  if (U in continuous):
    D = V
    C = U
  else:
    D = U
    C = V
  if debug: print(f'Discrete: {D} Continuous: {C}')
  responses = list(df[D].unique())
  if debug: print(f'responses = {responses}')
  pmi = list(mutual_info_regression(sparsify(df[D]), df[C], discrete_features=True))
  if debug: print(f'pmi list = {pmi}')
  l = []
  for i in list(range(0,(len(responses)))):
    conditional_probability = df[df[D]==responses[i]].shape[0]/len(df[C])
    l.append(pmi[i]*conditional_probability)
  mi = sum(l)
  if debug: print(f'MI: {mi}')
  return mi

# %%
# Test it out:
try: DC_mi(df.filter([random.choice(discrete),random.choice(continuous)]).dropna(how='any'))
except: pass
# Out:
# Calculating discrete-continious MI for icu_stay_type and pre_icu_los_days
# Discrete: icu_stay_type Continuous: pre_icu_los_days
# responses = ['admit', 'transfer', 'readmit']
# pmi list = [0.0034740935472736822, 0.0057010139759055, 0.0019828203586609305]
# MI: 0.0035765119082821714

# %% [markdown]
# ### Continuous-Continuous

# %%
def CC_mi(df):

  ''' Takes a subset df of two continuous features and calculates mutual information using SciKit's mutual_info_regression function '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]

  if debug: print(f'Calculating mutual information for {U} and {V}')

  mi = mutual_info_regression(df.filter([U]),df[V])[0]
  if debug: print(f'MI = {mi}')
  return mi

# %%
# Test it out:
try: CC_mi(df.filter(random.sample(continuous, 2)).dropna(how='any'))
except: pass
# Out:
# Calculating mutual information for d1_wbc_min and h1_arterial_pco2_min
# MI = 0.145457668766519

# %% [markdown]
# #### Comparison: Correlation

# %%
def CC_corr(df):

  ''' Takes two continuous feature names and calculates pearson correlation '''

  U=list(df.columns)[0]
  V=list(df.columns)[1]

  if debug: print(f'Calculating correlation between {U} and {V}')

  corr = pearsonr(df[U], df[V])[0]
  if debug: print(f'Correlation = {corr}')
  return corr

# %%
# Test it out:
try: CC_corr(df.filter(random.sample(continuous, 2)).dropna(how='any'))
except: pass
# Out:
# Calculating correlation between d1_mbp_noninvasive_min and d1_temp_min
# Correlation = 0.10594087011450387

# %% [markdown]
# ## Matrix Functions

# %%
def matrixify(df):
  ''' Takes a dataframe with columns [source,target,value] and returns a matrix where {index:source, columns:target, values:values} '''
  m = df.pivot(index=list(df.columns)[0], columns=list(df.columns)[1], values=list(df.columns)[2])
  return m

# %%
def stack(matrix,chart=False):
  ''' For undirected matrices: Takes a matrix and returns a dataframe with columns [x,y,v] corresponding to [source,target,value] '''
  s = pd.DataFrame(matrix.mask(np.triu(np.ones(matrix.shape)).astype(bool)).stack()).reset_index().rename(columns={'level_0':'x','level_1':'y',0:'v'})
  s = s[s['x']!=s['y']]
  s = s[s['v']>0]
  s = s.sort_values(by='v',ascending=False)
  #sns.distplot(s['v'],kde=False)
  return s

# %% [markdown]
# ## Data Processing

# %%
def calc_pairtype(U,V):

  ''' Takes two feature names and returns the pair type ('DD': discrete/discrete, 'DC': discrete/continuous, or 'CC': continuous/continuous) '''

  if debug: print('Finding pair type for "',U,'" and "',V,'"')
  # If both features are discrete:
  if ((U in discrete) and (V in discrete)):
    pair_type = 'DD'
    if debug: print('"',U,'" and "',V,'" are data pair type',pair_type)
  # If both features are continuous:
  elif ((U in continuous) and (V in continuous)):
    pair_type = 'CC'
    if debug: print('"',U,'" and "',V,'" are data pair type',pair_type)
  # If one feature is continuous and one feature is discrete:
  elif ((U in continuous) and (V in discrete)) or ((U in discrete) and (V in continuous)):
    pair_type = 'DC'
    if debug: print('"',U,'" and "',V,'" are data pair type',pair_type)
  else:
    pair_type = 'Err'
    print('Error on',U,'and',V)
  return pair_type

# %%
def calc_mi(U,V):

  ''' Takes two feature names and determines which mutual information method to use; returns calculated mutual information score '''

  try:
      pairdf = df.filter([U,V]).dropna(how='any')

      if pairdf.shape[0]<1:
        return 0

      if debug:
        print('Calculating mutual information for',U,'(',list(df.columns).index(U),'of',len(list(df.columns)),')',V,'(',list(df.columns).index(V),'of',len(list(df.columns)),')')
      mi_start_time = datetime.now()
      if (U==V):
        return 1
      else:
        pair_type = calc_pairtype(U,V)
        # If both features are discrete:
        if (pair_type=='DD'):
          mi = DD_mi(pairdf)
        # If both features are continuous:
        elif (pair_type=='CC'):
          mi = CC_mi(pairdf)
        # If one feature is continuous and one feature is discrete:
        elif (pair_type=='DC'):
          mi = DC_mi(pairdf)
        else:
          mi = 0
        if chart: viz(U,V)
        if debug: print('Elapsed time:',datetime.now() - mi_start_time)
      return mi
  except: return 0

# %%
def run_calc(features):
  start_time = datetime.now()

  if compare_all: matrix = pd.DataFrame(1, columns=features,index=features)
  else: matrix = pd.DataFrame(1, columns=list1,index=list2)
        
  s = stack(matrix)

  s['v'] = [calc_mi(x,y) for x,y in zip(s['x'],s['y'])]
  if debug:
    print('Elapsed time:',datetime.now() - start_time)
    print('Calcuated mutual information for',len(features),'columns across',df.shape[0],'records')
  return s

# %% [markdown]
# # Calculation

# %%
chart=False

# %%
stack = run_calc(list(df.columns))
# Out:
# Calculating mutual information for age ( 1 of 180 ) hospital_death ( 0 of 180 )
# Finding pair type for " age " and " hospital_death "
# " age " and " hospital_death " are data pair type DC
# Calculating discrete-continious MI for age and hospital_death
# Discrete: hospital_death Continuous: age
# responses = ['0', '1']
# pmi list = [0, 0]
# MI: 0.0
# MI: 0.0
# Elapsed time: 0:00:00.443130
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) albumin_apache ( 13 of 180 )
# Finding pair type for " h1_potassium_max " and " albumin_apache "
# " h1_potassium_max " and " albumin_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and albumin_apache
# MI = 0.4288658934806042
# MI: 0.4288658934806042
# Elapsed time: 0:00:00.533641
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) hospital_death ( 0 of 180 )
# Finding pair type for " h1_potassium_max " and " hospital_death "
# " h1_potassium_max " and " hospital_death " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and hospital_death
# Discrete: hospital_death Continuous: h1_potassium_max
# responses = ['0', '1']
# pmi list = [0, 0]
# MI: 0.0
# MI: 0.0
# Elapsed time: 0:00:00.249486
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) age ( 1 of 180 )
# Finding pair type for " h1_potassium_max " and " age "
# " h1_potassium_max " and " age " are data pair type CC
# Calculating mutual information for h1_potassium_max and age
# MI = 0.005026937374275509
# MI: 0.005026937374275509
# Elapsed time: 0:00:00.506094
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) bmi ( 2 of 180 )
# Finding pair type for " h1_potassium_max " and " bmi "
# " h1_potassium_max " and " bmi " are data pair type CC
# Calculating mutual information for h1_potassium_max and bmi
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.621795
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) elective_surgery ( 3 of 180 )
# Finding pair type for " h1_potassium_max " and " elective_surgery "
# " h1_potassium_max " and " elective_surgery " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and elective_surgery
# Discrete: elective_surgery Continuous: h1_potassium_max
# responses = ['0', '1']
# pmi list = [0.01814214062840902, 0.01814214062840902]
# MI: 0.01814214062840902
# MI: 0.01814214062840902
# Elapsed time: 0:00:00.270286
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) ethnicity ( 4 of 180 )
# Finding pair type for " h1_potassium_max " and " ethnicity "
# " h1_potassium_max " and " ethnicity " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and ethnicity
# Discrete: ethnicity Continuous: h1_potassium_max
# responses = ['Caucasian', 'Other/Unknown', 'African American', 'Native American', 'Hispanic', 'Asian']
# pmi list = [0.0, 0.00407883265014064, 0.0, 0.00012586894405963722, 0.0017038431823859224, 0.0]
# MI: 0.00029823384660599794
# MI: 0.00029823384660599794
# Elapsed time: 0:00:00.365635
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) gender ( 5 of 180 )
# Finding pair type for " h1_potassium_max " and " gender "
# " h1_potassium_max " and " gender " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and gender
# Discrete: gender Continuous: h1_potassium_max
# responses = ['F', 'M']
# pmi list = [0.005209265241350458, 0.005209265241350458]
# MI: 0.005209265241350458
# MI: 0.005209265241350458
# Elapsed time: 0:00:00.259160
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) height ( 6 of 180 )
# Finding pair type for " h1_potassium_max " and " height "
# " h1_potassium_max " and " height " are data pair type CC
# Calculating mutual information for h1_potassium_max and height
# MI = 0.0002607900910729377
# MI: 0.0002607900910729377
# Elapsed time: 0:00:00.593562
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) hospital_admit_source ( 7 of 180 )
# Finding pair type for " h1_potassium_max " and " hospital_admit_source "
# " h1_potassium_max " and " hospital_admit_source " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and hospital_admit_source
# Discrete: hospital_admit_source Continuous: h1_potassium_max
# responses = ['Emergency Department', 'PACU', 'Floor', 'Direct Admit', 'Acute Care/Floor', 'Operating Room', 'Step-Down Unit (SDU)', 'Chest Pain Center', 'Recovery Room', 'Other Hospital', 'Other ICU', 'ICU']
# pmi list = [0.03586853185190586, 9.843997657843495e-05, 0.012548677894151705, 0.005136570949096697, 0.015098813230519204, 0.02801987498877212, 0.0037308395063447852, 0.0, 0.0, 0.0010140416634196736, 0.0, 3.3306690738754696e-16]
# MI: 0.024801932886603546
# MI: 0.024801932886603546
# Elapsed time: 0:00:00.417878
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) icu_admit_source ( 8 of 180 )
# Finding pair type for " h1_potassium_max " and " icu_admit_source "
# " h1_potassium_max " and " icu_admit_source " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and icu_admit_source
# Discrete: icu_admit_source Continuous: h1_potassium_max
# responses = ['Accident & Emergency', 'Operating Room / Recovery', 'Floor', 'Other ICU', 'Other Hospital']
# pmi list = [0.0, 0.0, 0.003406333770423986, 0.0, 0.004519263101318671]
# MI: 0.0007188288630445941
# MI: 0.0007188288630445941
# Elapsed time: 0:00:00.325362
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) icu_stay_type ( 9 of 180 )
# Finding pair type for " h1_potassium_max " and " icu_stay_type "
# " h1_potassium_max " and " icu_stay_type " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and icu_stay_type
# Discrete: icu_stay_type Continuous: h1_potassium_max
# responses = ['admit', 'transfer', 'readmit']
# pmi list = [0.013616799198335361, 0.015800325629533818, 0.0]
# MI: 0.0136793248508367
# MI: 0.0136793248508367
# Elapsed time: 0:00:00.300099
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) icu_type ( 10 of 180 )
# Finding pair type for " h1_potassium_max " and " icu_type "
# " h1_potassium_max " and " icu_type " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and icu_type
# Discrete: icu_type Continuous: h1_potassium_max
# responses = ['Med-Surg ICU', 'SICU', 'CSICU', 'Cardiac ICU', 'CCU-CTICU', 'Neuro ICU', 'MICU', 'CTICU']
# pmi list = [0.0, 0.0, 1.4308762584347434e-05, 9.136667341436144e-05, 0.0010661434447960527, 0.008580496549855265, 0.0008840106746008658, 0.0009884996098314947]
# MI: 0.0009572088649020117
# MI: 0.0009572088649020117
# Elapsed time: 0:00:00.480169
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) pre_icu_los_days ( 11 of 180 )
# Finding pair type for " h1_potassium_max " and " pre_icu_los_days "
# " h1_potassium_max " and " pre_icu_los_days " are data pair type CC
# Calculating mutual information for h1_potassium_max and pre_icu_los_days
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.444796
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) weight ( 12 of 180 )
# Finding pair type for " h1_potassium_max " and " weight "
# " h1_potassium_max " and " weight " are data pair type CC
# Calculating mutual information for h1_potassium_max and weight
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.474129
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) apache_2_diagnosis ( 14 of 180 )
# Finding pair type for " h1_potassium_max " and " apache_2_diagnosis "
# " h1_potassium_max " and " apache_2_diagnosis " are data pair type CC
# Calculating mutual information for h1_potassium_max and apache_2_diagnosis
# MI = 0.01469156258076243
# MI: 0.01469156258076243
# Elapsed time: 0:00:00.530756
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) intubated_apache ( 29 of 180 )
# Finding pair type for " h1_potassium_max " and " intubated_apache "
# " h1_potassium_max " and " intubated_apache " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and intubated_apache
# Discrete: intubated_apache Continuous: h1_potassium_max
# responses = ['0.0', '1.0']
# pmi list = [0, 0]
# MI: 0.0
# MI: 0.0
# Elapsed time: 0:00:00.238948
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) apache_3j_diagnosis ( 15 of 180 )
# Finding pair type for " h1_potassium_max " and " apache_3j_diagnosis "
# " h1_potassium_max " and " apache_3j_diagnosis " are data pair type CC
# Calculating mutual information for h1_potassium_max and apache_3j_diagnosis
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.451458
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) apache_post_operative ( 16 of 180 )
# Finding pair type for " h1_potassium_max " and " apache_post_operative "
# " h1_potassium_max " and " apache_post_operative " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and apache_post_operative
# Discrete: apache_post_operative Continuous: h1_potassium_max
# responses = ['0', '1']
# pmi list = [0.01394405112677366, 0.01394405112677366]
# MI: 0.01394405112677366
# MI: 0.01394405112677366
# Elapsed time: 0:00:00.247877
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) arf_apache ( 17 of 180 )
# Finding pair type for " h1_potassium_max " and " arf_apache "
# " h1_potassium_max " and " arf_apache " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and arf_apache
# Discrete: arf_apache Continuous: h1_potassium_max
# responses = ['0.0', '1.0']
# pmi list = [0.01223307599529444, 0.01223307599529444]
# MI: 0.01223307599529444
# MI: 0.01223307599529444
# Elapsed time: 0:00:00.244921
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) bilirubin_apache ( 18 of 180 )
# Finding pair type for " h1_potassium_max " and " bilirubin_apache "
# " h1_potassium_max " and " bilirubin_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and bilirubin_apache
# MI = 0.4849333925151118
# MI: 0.4849333925151118
# Elapsed time: 0:00:00.584241
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) bun_apache ( 19 of 180 )
# Finding pair type for " h1_potassium_max " and " bun_apache "
# " h1_potassium_max " and " bun_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and bun_apache
# MI = 0.14208206658024558
# MI: 0.14208206658024558
# Elapsed time: 0:00:00.441941
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) creatinine_apache ( 20 of 180 )
# Finding pair type for " h1_potassium_max " and " creatinine_apache "
# " h1_potassium_max " and " creatinine_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and creatinine_apache
# MI = 0.29974157236184595
# MI: 0.29974157236184595
# Elapsed time: 0:00:00.468372
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) fio2_apache ( 21 of 180 )
# Finding pair type for " h1_potassium_max " and " fio2_apache "
# " h1_potassium_max " and " fio2_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and fio2_apache
# MI = 0.46094236388390275
# MI: 0.46094236388390275
# Elapsed time: 0:00:00.549272
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) gcs_eyes_apache ( 22 of 180 )
# Finding pair type for " h1_potassium_max " and " gcs_eyes_apache "
# " h1_potassium_max " and " gcs_eyes_apache " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and gcs_eyes_apache
# Discrete: gcs_eyes_apache Continuous: h1_potassium_max
# responses = ['4.0', '2.0', '3.0', '1.0']
# pmi list = [0.0, 0.0, 0.006944588484789627, 0.0]
# MI: 0.000998108871295675
# MI: 0.000998108871295675
# Elapsed time: 0:00:00.304499
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) gcs_motor_apache ( 23 of 180 )
# Finding pair type for " h1_potassium_max " and " gcs_motor_apache "
# " h1_potassium_max " and " gcs_motor_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and gcs_motor_apache
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.421069
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) gcs_unable_apache ( 24 of 180 )
# Finding pair type for " h1_potassium_max " and " gcs_unable_apache "
# " h1_potassium_max " and " gcs_unable_apache " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and gcs_unable_apache
# Discrete: gcs_unable_apache Continuous: h1_potassium_max
# responses = ['0.0', '1.0']
# pmi list = [0.002714635100039997, 0.002714635100039997]
# MI: 0.002714635100039997
# MI: 0.002714635100039997
# Elapsed time: 0:00:00.254418
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) gcs_verbal_apache ( 25 of 180 )
# Finding pair type for " h1_potassium_max " and " gcs_verbal_apache "
# " h1_potassium_max " and " gcs_verbal_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and gcs_verbal_apache
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.539966
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) glucose_apache ( 26 of 180 )
# Finding pair type for " h1_potassium_max " and " glucose_apache "
# " h1_potassium_max " and " glucose_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and glucose_apache
# MI = 0.1433253835974324
# MI: 0.1433253835974324
# Elapsed time: 0:00:00.596847
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) heart_rate_apache ( 27 of 180 )
# Finding pair type for " h1_potassium_max " and " heart_rate_apache "
# " h1_potassium_max " and " heart_rate_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and heart_rate_apache
# MI = 0.060019023254850534
# MI: 0.060019023254850534
# Elapsed time: 0:00:00.623222
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_platelets_max ( 145 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_platelets_max "
# " h1_platelets_min " and " h1_platelets_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_platelets_max
# MI = 4.51973813319691
# MI: 4.51973813319691
# Elapsed time: 0:00:00.591548
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_lactate_min ( 144 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_lactate_min "
# " h1_platelets_min " and " h1_lactate_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_lactate_min
# MI = 2.468027567222004
# MI: 2.468027567222004
# Elapsed time: 0:00:00.441173
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_lactate_max ( 143 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_lactate_max "
# " h1_platelets_min " and " h1_lactate_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_lactate_max
# MI = 2.5574158701391934
# MI: 2.5574158701391934
# Elapsed time: 0:00:00.472008
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_inr_min ( 142 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_inr_min "
# " h1_platelets_min " and " h1_inr_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_inr_min
# MI = 1.0905013491772602
# MI: 1.0905013491772602
# Elapsed time: 0:00:00.611446
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_platelets_max ( 115 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_platelets_max "
# " h1_platelets_min " and " d1_platelets_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_platelets_max
# MI = 0.5243425080991178
# MI: 0.5243425080991178
# Elapsed time: 0:00:00.407912
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_platelets_min ( 116 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_platelets_min "
# " h1_platelets_min " and " d1_platelets_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_platelets_min
# MI = 0.42188199587759945
# MI: 0.42188199587759945
# Elapsed time: 0:00:00.425816
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_potassium_max ( 117 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_potassium_max "
# " h1_platelets_min " and " d1_potassium_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_potassium_max
# MI = 0.17331158108117384
# MI: 0.17331158108117384
# Elapsed time: 0:00:00.588336
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_potassium_min ( 118 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_potassium_min "
# " h1_platelets_min " and " d1_potassium_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_potassium_min
# MI = 0.12992123908725395
# MI: 0.12992123908725395
# Elapsed time: 0:00:00.488871
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_sodium_max ( 119 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_sodium_max "
# " h1_platelets_min " and " d1_sodium_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_sodium_max
# MI = 0.10071190961873988
# MI: 0.10071190961873988
# Elapsed time: 0:00:00.424542
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_sodium_min ( 120 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_sodium_min "
# " h1_platelets_min " and " d1_sodium_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_sodium_min
# MI = 0.08080126819897782
# MI: 0.08080126819897782
# Elapsed time: 0:00:00.429140
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_wbc_max ( 121 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_wbc_max "
# " h1_platelets_min " and " d1_wbc_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_wbc_max
# MI = 0.18184295133375672
# MI: 0.18184295133375672
# Elapsed time: 0:00:00.550874
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_wbc_min ( 122 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_wbc_min "
# " h1_platelets_min " and " d1_wbc_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_wbc_min
# MI = 0.1662730793908178
# MI: 0.1662730793908178
# Elapsed time: 0:00:00.455102
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_albumin_max ( 123 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_albumin_max "
# " h1_platelets_min " and " h1_albumin_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_albumin_max
# MI = 2.011183434157554
# MI: 2.011183434157554
# Elapsed time: 0:00:00.401830
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_albumin_min ( 124 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_albumin_min "
# " h1_platelets_min " and " h1_albumin_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_albumin_min
# MI = 2.0713086826301907
# MI: 2.0713086826301907
# Elapsed time: 0:00:00.526178
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_bilirubin_max ( 125 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_bilirubin_max "
# " h1_platelets_min " and " h1_bilirubin_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_bilirubin_max
# MI = 1.844811930837631
# MI: 1.844811930837631
# Elapsed time: 0:00:00.441500
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_bilirubin_min ( 126 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_bilirubin_min "
# " h1_platelets_min " and " h1_bilirubin_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_bilirubin_min
# MI = 1.85908783436639
# MI: 1.85908783436639
# Elapsed time: 0:00:00.434871
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_bun_max ( 127 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_bun_max "
# " h1_platelets_min " and " h1_bun_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_bun_max
# MI = 2.3816334169447293
# MI: 2.3816334169447293
# Elapsed time: 0:00:00.593538
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_bun_min ( 128 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_bun_min "
# " h1_platelets_min " and " h1_bun_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_bun_min
# MI = 2.3562268271893885
# MI: 2.3562268271893885
# Elapsed time: 0:00:00.414625
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_calcium_max ( 129 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_calcium_max "
# " h1_platelets_min " and " h1_calcium_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_calcium_max
# MI = 2.2078354700603944
# MI: 2.2078354700603944
# Elapsed time: 0:00:00.401859
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_calcium_min ( 130 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_calcium_min "
# " h1_platelets_min " and " h1_calcium_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_calcium_min
# MI = 2.195425152766619
# MI: 2.195425152766619
# Elapsed time: 0:00:00.544793
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_creatinine_max ( 131 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_creatinine_max "
# " h1_platelets_min " and " h1_creatinine_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_creatinine_max
# MI = 2.8247854601615434
# MI: 2.8247854601615434
# Elapsed time: 0:00:00.393066
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_creatinine_min ( 132 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_creatinine_min "
# " h1_platelets_min " and " h1_creatinine_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_creatinine_min
# MI = 2.805222402181706
# MI: 2.805222402181706
# Elapsed time: 0:00:00.418416
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_glucose_max ( 133 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_glucose_max "
# " h1_platelets_min " and " h1_glucose_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_glucose_max
# MI = 1.5968906131970408
# MI: 1.5968906131970408
# Elapsed time: 0:00:00.404112
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_glucose_min ( 134 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_glucose_min "
# " h1_platelets_min " and " h1_glucose_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_glucose_min
# MI = 1.5442210404042611
# MI: 1.5442210404042611
# Elapsed time: 0:00:00.529370
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_hco3_max ( 135 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_hco3_max "
# " h1_platelets_min " and " h1_hco3_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_hco3_max
# MI = 2.007797283523922
# MI: 2.007797283523922
# Elapsed time: 0:00:00.457497
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_hco3_min ( 136 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_hco3_min "
# " h1_platelets_min " and " h1_hco3_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_hco3_min
# MI = 1.939993200064671
# MI: 1.939993200064671
# Elapsed time: 0:00:00.398023
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_hemaglobin_max ( 137 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_hemaglobin_max "
# " h1_platelets_min " and " h1_hemaglobin_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_hemaglobin_max
# MI = 2.797427687736852
# MI: 2.797427687736852
# Elapsed time: 0:00:00.596468
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_hemaglobin_min ( 138 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_hemaglobin_min "
# " h1_platelets_min " and " h1_hemaglobin_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_hemaglobin_min
# MI = 2.809348919890865
# MI: 2.809348919890865
# Elapsed time: 0:00:00.480633
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_hematocrit_max ( 139 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_hematocrit_max "
# " h1_platelets_min " and " h1_hematocrit_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_hematocrit_max
# MI = 3.147239961402755
# MI: 3.147239961402755
# Elapsed time: 0:00:00.489614
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_hematocrit_min ( 140 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_hematocrit_min "
# " h1_platelets_min " and " h1_hematocrit_min " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_hematocrit_min
# MI = 3.160884005851944
# MI: 3.160884005851944
# Elapsed time: 0:00:00.613929
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) h1_inr_max ( 141 of 180 )
# Finding pair type for " h1_platelets_min " and " h1_inr_max "
# " h1_platelets_min " and " h1_inr_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and h1_inr_max
# MI = 1.1572137696598324
# MI: 1.1572137696598324
# Elapsed time: 0:00:00.477299
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) hematocrit_apache ( 28 of 180 )
# Finding pair type for " h1_potassium_max " and " hematocrit_apache "
# " h1_potassium_max " and " hematocrit_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and hematocrit_apache
# MI = 0.30075270111588814
# MI: 0.30075270111588814
# Elapsed time: 0:00:00.457156
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) map_apache ( 30 of 180 )
# Finding pair type for " h1_potassium_max " and " map_apache "
# " h1_potassium_max " and " map_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and map_apache
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.492379
# Calculating mutual information for h1_platelets_min ( 146 of 180 ) d1_lactate_max ( 113 of 180 )
# Finding pair type for " h1_platelets_min " and " d1_lactate_max "
# " h1_platelets_min " and " d1_lactate_max " are data pair type CC
# Calculating mutual information for h1_platelets_min and d1_lactate_max
# MI = 1.6840291601917787
# MI: 1.6840291601917787
# Elapsed time: 0:00:00.594243
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_mbp_invasive_min ( 76 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_mbp_invasive_min "
# " h1_potassium_max " and " h1_mbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_mbp_invasive_min
# MI = 1.1467161372528736
# MI: 1.1467161372528736
# Elapsed time: 0:00:00.450653
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_sysbp_noninvasive_max ( 63 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_sysbp_noninvasive_max "
# " h1_potassium_max " and " d1_sysbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_sysbp_noninvasive_max
# MI = 0.0025092365056984534
# MI: 0.0025092365056984534
# Elapsed time: 0:00:00.489836
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_sysbp_noninvasive_min ( 64 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_sysbp_noninvasive_min "
# " h1_potassium_max " and " d1_sysbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_sysbp_noninvasive_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.600093
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_temp_max ( 65 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_temp_max "
# " h1_potassium_max " and " d1_temp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_temp_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.457383
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_temp_min ( 66 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_temp_min "
# " h1_potassium_max " and " d1_temp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_temp_min
# MI = 0.019903944395535778
# MI: 0.019903944395535778
# Elapsed time: 0:00:00.531207
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_diasbp_invasive_max ( 67 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_diasbp_invasive_max "
# " h1_potassium_max " and " h1_diasbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_diasbp_invasive_max
# MI = 1.1344821245630752
# MI: 1.1344821245630752
# Elapsed time: 0:00:00.655842
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_diasbp_invasive_min ( 68 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_diasbp_invasive_min "
# " h1_potassium_max " and " h1_diasbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_diasbp_invasive_min
# MI = 1.0573217672154995
# MI: 1.0573217672154995
# Elapsed time: 0:00:00.492639
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_diasbp_max ( 69 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_diasbp_max "
# " h1_potassium_max " and " h1_diasbp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_diasbp_max
# MI = 0.04248527290312376
# MI: 0.04248527290312376
# Elapsed time: 0:00:00.496149
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_diasbp_min ( 70 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_diasbp_min "
# " h1_potassium_max " and " h1_diasbp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_diasbp_min
# MI = 0.004384575363054033
# MI: 0.004384575363054033
# Elapsed time: 0:00:00.643771
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_diasbp_noninvasive_max ( 71 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_diasbp_noninvasive_max "
# " h1_potassium_max " and " h1_diasbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_diasbp_noninvasive_max
# MI = 0.07703559068198151
# MI: 0.07703559068198151
# Elapsed time: 0:00:00.498808
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_diasbp_noninvasive_min ( 72 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_diasbp_noninvasive_min "
# " h1_potassium_max " and " h1_diasbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_diasbp_noninvasive_min
# MI = 0.01913513827026092
# MI: 0.01913513827026092
# Elapsed time: 0:00:00.485151
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_heartrate_max ( 73 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_heartrate_max "
# " h1_potassium_max " and " h1_heartrate_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_heartrate_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.504381
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_heartrate_min ( 74 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_heartrate_min "
# " h1_potassium_max " and " h1_heartrate_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_heartrate_min
# MI = 0.017526660253004422
# MI: 0.017526660253004422
# Elapsed time: 0:00:00.591698
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_mbp_invasive_max ( 75 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_mbp_invasive_max "
# " h1_potassium_max " and " h1_mbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_mbp_invasive_max
# MI = 1.1854424189300432
# MI: 1.1854424189300432
# Elapsed time: 0:00:00.490357
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_mbp_max ( 77 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_mbp_max "
# " h1_potassium_max " and " h1_mbp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_mbp_max
# MI = 0.04602203870870758
# MI: 0.04602203870870758
# Elapsed time: 0:00:00.453908
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) paco2_apache ( 31 of 180 )
# Finding pair type for " h1_potassium_max " and " paco2_apache "
# " h1_potassium_max " and " paco2_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and paco2_apache
# MI = 1.3212870761691358
# MI: 1.3212870761691358
# Elapsed time: 0:00:00.590559
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_mbp_min ( 78 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_mbp_min "
# " h1_potassium_max " and " h1_mbp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_mbp_min
# MI = 0.02280846793139668
# MI: 0.02280846793139668
# Elapsed time: 0:00:00.496525
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_mbp_noninvasive_max ( 79 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_mbp_noninvasive_max "
# " h1_potassium_max " and " h1_mbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_mbp_noninvasive_max
# MI = 0.05775163838302655
# MI: 0.05775163838302655
# Elapsed time: 0:00:00.552003
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_mbp_noninvasive_min ( 80 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_mbp_noninvasive_min "
# " h1_potassium_max " and " h1_mbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_mbp_noninvasive_min
# MI = 0.04572961871268255
# MI: 0.04572961871268255
# Elapsed time: 0:00:00.645743
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_resprate_max ( 81 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_resprate_max "
# " h1_potassium_max " and " h1_resprate_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_resprate_max
# MI = 0.0022858099861213788
# MI: 0.0022858099861213788
# Elapsed time: 0:00:00.540970
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_resprate_min ( 82 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_resprate_min "
# " h1_potassium_max " and " h1_resprate_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_resprate_min
# MI = 0.0013413445803198698
# MI: 0.0013413445803198698
# Elapsed time: 0:00:00.494612
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_spo2_max ( 83 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_spo2_max "
# " h1_potassium_max " and " h1_spo2_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_spo2_max
# MI = 0.00815843760106194
# MI: 0.00815843760106194
# Elapsed time: 0:00:00.640134
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_spo2_min ( 84 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_spo2_min "
# " h1_potassium_max " and " h1_spo2_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_spo2_min
# MI = 0.031774153478611566
# MI: 0.031774153478611566
# Elapsed time: 0:00:00.495171
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_sysbp_invasive_max ( 85 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_sysbp_invasive_max "
# " h1_potassium_max " and " h1_sysbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_sysbp_invasive_max
# MI = 1.256232356450608
# MI: 1.256232356450608
# Elapsed time: 0:00:00.453959
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_sysbp_invasive_min ( 86 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_sysbp_invasive_min "
# " h1_potassium_max " and " h1_sysbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_sysbp_invasive_min
# MI = 1.2257027873319557
# MI: 1.2257027873319557
# Elapsed time: 0:00:00.533964
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_sysbp_max ( 87 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_sysbp_max "
# " h1_potassium_max " and " h1_sysbp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_sysbp_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.611481
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_sysbp_min ( 88 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_sysbp_min "
# " h1_potassium_max " and " h1_sysbp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_sysbp_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.538766
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_sysbp_noninvasive_max ( 89 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_sysbp_noninvasive_max "
# " h1_potassium_max " and " h1_sysbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_sysbp_noninvasive_max
# MI = 0.02797859868255559
# MI: 0.02797859868255559
# Elapsed time: 0:00:00.551264
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) h1_sysbp_noninvasive_min ( 90 of 180 )
# Finding pair type for " h1_potassium_max " and " h1_sysbp_noninvasive_min "
# " h1_potassium_max " and " h1_sysbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and h1_sysbp_noninvasive_min
# MI = 0.02951390190448544
# MI: 0.02951390190448544
# Elapsed time: 0:00:00.598561
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_sysbp_min ( 62 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_sysbp_min "
# " h1_potassium_max " and " d1_sysbp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_sysbp_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.495316
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_sysbp_max ( 61 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_sysbp_max "
# " h1_potassium_max " and " d1_sysbp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_sysbp_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.441152
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_sysbp_invasive_min ( 60 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_sysbp_invasive_min "
# " h1_potassium_max " and " d1_sysbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_sysbp_invasive_min
# MI = 0.9696014474914563
# MI: 0.9696014474914563
# Elapsed time: 0:00:00.499312
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_sysbp_invasive_max ( 59 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_sysbp_invasive_max "
# " h1_potassium_max " and " d1_sysbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_sysbp_invasive_max
# MI = 1.0410620380787674
# MI: 1.0410620380787674
# Elapsed time: 0:00:00.646581
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) paco2_for_ph_apache ( 32 of 180 )
# Finding pair type for " h1_potassium_max " and " paco2_for_ph_apache "
# " h1_potassium_max " and " paco2_for_ph_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and paco2_for_ph_apache
# MI = 1.3681319532014284
# MI: 1.3681319532014284
# Elapsed time: 0:00:00.547094
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) pao2_apache ( 33 of 180 )
# Finding pair type for " h1_potassium_max " and " pao2_apache "
# " h1_potassium_max " and " pao2_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and pao2_apache
# MI = 1.3926833407548815
# MI: 1.3926833407548815
# Elapsed time: 0:00:00.492385
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) ph_apache ( 34 of 180 )
# Finding pair type for " h1_potassium_max " and " ph_apache "
# " h1_potassium_max " and " ph_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and ph_apache
# MI = 1.1524182966981158
# MI: 1.1524182966981158
# Elapsed time: 0:00:00.592148
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) resprate_apache ( 35 of 180 )
# Finding pair type for " h1_potassium_max " and " resprate_apache "
# " h1_potassium_max " and " resprate_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and resprate_apache
# MI = 0.025910935566123783
# MI: 0.025910935566123783
# Elapsed time: 0:00:00.500403
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) sodium_apache ( 36 of 180 )
# Finding pair type for " h1_potassium_max " and " sodium_apache "
# " h1_potassium_max " and " sodium_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and sodium_apache
# MI = 0.08255350956617669
# MI: 0.08255350956617669
# Elapsed time: 0:00:00.542461
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) temp_apache ( 37 of 180 )
# Finding pair type for " h1_potassium_max " and " temp_apache "
# " h1_potassium_max " and " temp_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and temp_apache
# MI = 0.007776298976506446
# MI: 0.007776298976506446
# Elapsed time: 0:00:00.597859
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) urineoutput_apache ( 38 of 180 )
# Finding pair type for " h1_potassium_max " and " urineoutput_apache "
# " h1_potassium_max " and " urineoutput_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and urineoutput_apache
# MI = 0.7671040154258231
# MI: 0.7671040154258231
# Elapsed time: 0:00:00.646812
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) ventilated_apache ( 39 of 180 )
# Finding pair type for " h1_potassium_max " and " ventilated_apache "
# " h1_potassium_max " and " ventilated_apache " are data pair type DC
# Calculating discrete-continious MI for h1_potassium_max and ventilated_apache
# Discrete: ventilated_apache Continuous: h1_potassium_max
# responses = ['0.0', '1.0']
# pmi list = [0, 0]
# MI: 0.0
# MI: 0.0
# Elapsed time: 0:00:00.291004
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) wbc_apache ( 40 of 180 )
# Finding pair type for " h1_potassium_max " and " wbc_apache "
# " h1_potassium_max " and " wbc_apache " are data pair type CC
# Calculating mutual information for h1_potassium_max and wbc_apache
# MI = 0.26374777466735955
# MI: 0.26374777466735955
# Elapsed time: 0:00:00.488938
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_diasbp_invasive_max ( 41 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_diasbp_invasive_max "
# " h1_potassium_max " and " d1_diasbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_diasbp_invasive_max
# MI = 0.9359004233679147
# MI: 0.9359004233679147
# Elapsed time: 0:00:00.549935
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_diasbp_invasive_min ( 42 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_diasbp_invasive_min "
# " h1_potassium_max " and " d1_diasbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_diasbp_invasive_min
# MI = 0.8186139454591244
# MI: 0.8186139454591244
# Elapsed time: 0:00:00.600150
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_diasbp_max ( 43 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_diasbp_max "
# " h1_potassium_max " and " d1_diasbp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_diasbp_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.496451
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_diasbp_min ( 44 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_diasbp_min "
# " h1_potassium_max " and " d1_diasbp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_diasbp_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.586253
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_diasbp_noninvasive_max ( 45 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_diasbp_noninvasive_max "
# " h1_potassium_max " and " d1_diasbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_diasbp_noninvasive_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.748540
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_diasbp_noninvasive_min ( 46 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_diasbp_noninvasive_min "
# " h1_potassium_max " and " d1_diasbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_diasbp_noninvasive_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.498667
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_heartrate_max ( 47 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_heartrate_max "
# " h1_potassium_max " and " d1_heartrate_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_heartrate_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.517375
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_heartrate_min ( 48 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_heartrate_min "
# " h1_potassium_max " and " d1_heartrate_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_heartrate_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.482348
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_mbp_invasive_max ( 49 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_mbp_invasive_max "
# " h1_potassium_max " and " d1_mbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_mbp_invasive_max
# MI = 0.9593241863173505
# MI: 0.9593241863173505
# Elapsed time: 0:00:00.733795
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_mbp_invasive_min ( 50 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_mbp_invasive_min "
# " h1_potassium_max " and " d1_mbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_mbp_invasive_min
# MI = 0.993044134285709
# MI: 0.993044134285709
# Elapsed time: 0:00:00.592877
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_mbp_max ( 51 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_mbp_max "
# " h1_potassium_max " and " d1_mbp_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_mbp_max
# MI = 0.018374964174482145
# MI: 0.018374964174482145
# Elapsed time: 0:00:00.552338
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_mbp_min ( 52 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_mbp_min "
# " h1_potassium_max " and " d1_mbp_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_mbp_min
# MI = 0.00034322772573558424
# MI: 0.00034322772573558424
# Elapsed time: 0:00:00.692067
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_mbp_noninvasive_max ( 53 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_mbp_noninvasive_max "
# " h1_potassium_max " and " d1_mbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_mbp_noninvasive_max
# MI = 0.020989164508992797
# MI: 0.020989164508992797
# Elapsed time: 0:00:00.554270
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_mbp_noninvasive_min ( 54 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_mbp_noninvasive_min "
# " h1_potassium_max " and " d1_mbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_mbp_noninvasive_min
# MI = 0.014497364626079978
# MI: 0.014497364626079978
# Elapsed time: 0:00:00.493980
# Calculating mutual information for h1_potassium_max ( 147 of 180 ) d1_resprate_max ( 55 of 180 )
# Finding pair type for " h1_potassium_max " and " d1_resprate_max "
# " h1_potassium_max " and " d1_resprate_max " are data pair type CC
# Calculating mutual information for h1_potassium_max and d1_resprate_max
# MI = 0.01464746728926869
# MI: 0.01464746728926869
# Elapsed time: 0:00:00.549136
# ...
# " h1_pao2fio2ratio_min " and " d1_diasbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_diasbp_invasive_min
# MI = 1.6317799059212184
# MI: 1.6317799059212184
# Elapsed time: 0:00:00.557930
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_diasbp_max ( 43 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_diasbp_max "
# " h1_pao2fio2ratio_min " and " d1_diasbp_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_diasbp_max
# MI = 0.000872205228888312
# MI: 0.000872205228888312
# Elapsed time: 0:00:00.533646
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_diasbp_min ( 44 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_diasbp_min "
# " h1_pao2fio2ratio_min " and " d1_diasbp_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_diasbp_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.600575
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_diasbp_noninvasive_max ( 45 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_diasbp_noninvasive_max "
# " h1_pao2fio2ratio_min " and " d1_diasbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_diasbp_noninvasive_max
# MI = 0.0120913586225333
# MI: 0.0120913586225333
# Elapsed time: 0:00:00.541370
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_diasbp_noninvasive_min ( 46 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_diasbp_noninvasive_min "
# " h1_pao2fio2ratio_min " and " d1_diasbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_diasbp_noninvasive_min
# MI = 0.0041524701433810485
# MI: 0.0041524701433810485
# Elapsed time: 0:00:00.552464
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_heartrate_max ( 47 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_heartrate_max "
# " h1_pao2fio2ratio_min " and " d1_heartrate_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_heartrate_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.540016
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_heartrate_min ( 48 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_heartrate_min "
# " h1_pao2fio2ratio_min " and " d1_heartrate_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_heartrate_min
# MI = 0.0312730970429862
# MI: 0.0312730970429862
# Elapsed time: 0:00:00.496566
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_mbp_invasive_max ( 49 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_mbp_invasive_max "
# " h1_pao2fio2ratio_min " and " d1_mbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_mbp_invasive_max
# MI = 1.8235133379281518
# MI: 1.8235133379281518
# Elapsed time: 0:00:00.548731
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_mbp_invasive_min ( 50 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_mbp_invasive_min "
# " h1_pao2fio2ratio_min " and " d1_mbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_mbp_invasive_min
# MI = 1.854843432647177
# MI: 1.854843432647177
# Elapsed time: 0:00:01.794001
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_mbp_max ( 51 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_mbp_max "
# " h1_pao2fio2ratio_min " and " d1_mbp_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_mbp_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.597273
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_mbp_noninvasive_max ( 53 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_mbp_noninvasive_max "
# " h1_pao2fio2ratio_min " and " d1_mbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_mbp_noninvasive_max
# MI = 0.012285386656854413
# MI: 0.012285386656854413
# Elapsed time: 0:00:00.491804
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) hospital_admit_source ( 7 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " hospital_admit_source "
# " h1_pao2fio2ratio_min " and " hospital_admit_source " are data pair type DC
# Calculating discrete-continious MI for h1_pao2fio2ratio_min and hospital_admit_source
# Discrete: hospital_admit_source Continuous: h1_pao2fio2ratio_min
# responses = ['Operating Room', 'Emergency Department', 'Floor', 'PACU', 'Direct Admit', 'Acute Care/Floor', 'Step-Down Unit (SDU)', 'Chest Pain Center', 'Recovery Room', 'Other Hospital', 'Other ICU', 'ICU']
# pmi list = [0.014852999639717535, 0.04919838365740947, 0.03040947726171228, 0.0009215637119429632, 0.03850876505746914, 0.011180809161351002, 0.0, 0.0017799936408787742, 0.0009355155582526642, 0.0, 0.0, 0.0]
# MI: 0.03497948116999862
# MI: 0.03497948116999862
# Elapsed time: 0:00:00.609049
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_mbp_noninvasive_min ( 54 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_mbp_noninvasive_min "
# " h1_pao2fio2ratio_min " and " d1_mbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_mbp_noninvasive_min
# MI = 0.020494606017082084
# MI: 0.020494606017082084
# Elapsed time: 0:00:00.582925
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_resprate_max ( 55 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_resprate_max "
# " h1_pao2fio2ratio_min " and " d1_resprate_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_resprate_max
# MI = 0.052287023406716315
# MI: 0.052287023406716315
# Elapsed time: 0:00:00.541893
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_resprate_min ( 56 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_resprate_min "
# " h1_pao2fio2ratio_min " and " d1_resprate_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_resprate_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.584896
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_spo2_max ( 57 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_spo2_max "
# " h1_pao2fio2ratio_min " and " d1_spo2_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_spo2_max
# MI = 0.03097221097371161
# MI: 0.03097221097371161
# Elapsed time: 0:00:00.508226
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_spo2_min ( 58 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_spo2_min "
# " h1_pao2fio2ratio_min " and " d1_spo2_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_spo2_min
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.545235
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_sysbp_invasive_max ( 59 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_sysbp_invasive_max "
# " h1_pao2fio2ratio_min " and " d1_sysbp_invasive_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_sysbp_invasive_max
# MI = 1.9959490726329059
# MI: 1.9959490726329059
# Elapsed time: 0:00:00.549097
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_sysbp_invasive_min ( 60 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_sysbp_invasive_min "
# " h1_pao2fio2ratio_min " and " d1_sysbp_invasive_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_sysbp_invasive_min
# MI = 1.9433634491096394
# MI: 1.9433634491096394
# Elapsed time: 0:00:00.495096
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_sysbp_max ( 61 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_sysbp_max "
# " h1_pao2fio2ratio_min " and " d1_sysbp_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_sysbp_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.565950
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_sysbp_min ( 62 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_sysbp_min "
# " h1_pao2fio2ratio_min " and " d1_sysbp_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_sysbp_min
# MI = 0.031083072343478957
# MI: 0.031083072343478957
# Elapsed time: 0:00:00.530217
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_sysbp_noninvasive_max ( 63 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_sysbp_noninvasive_max "
# " h1_pao2fio2ratio_min " and " d1_sysbp_noninvasive_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_sysbp_noninvasive_max
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.549332
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_sysbp_noninvasive_min ( 64 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_sysbp_noninvasive_min "
# " h1_pao2fio2ratio_min " and " d1_sysbp_noninvasive_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_sysbp_noninvasive_min
# MI = 0.03511858983452232
# MI: 0.03511858983452232
# Elapsed time: 0:00:00.489233
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_temp_max ( 65 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_temp_max "
# " h1_pao2fio2ratio_min " and " d1_temp_max " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_temp_max
# MI = 0.05108071494111632
# MI: 0.05108071494111632
# Elapsed time: 0:00:00.495525
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) d1_temp_min ( 66 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " d1_temp_min "
# " h1_pao2fio2ratio_min " and " d1_temp_min " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and d1_temp_min
# MI = 0.04220924271595994
# MI: 0.04220924271595994
# Elapsed time: 0:00:00.547386
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) urineoutput_apache ( 38 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " urineoutput_apache "
# " h1_pao2fio2ratio_min " and " urineoutput_apache " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and urineoutput_apache
# MI = 1.179738305594845
# MI: 1.179738305594845
# Elapsed time: 0:00:00.500521
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) temp_apache ( 37 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " temp_apache "
# " h1_pao2fio2ratio_min " and " temp_apache " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and temp_apache
# MI = 0.04554353004803868
# MI: 0.04554353004803868
# Elapsed time: 0:00:00.494567
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) sodium_apache ( 36 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " sodium_apache "
# " h1_pao2fio2ratio_min " and " sodium_apache " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and sodium_apache
# MI = 0.1787446559321384
# MI: 0.1787446559321384
# Elapsed time: 0:00:00.541103
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) resprate_apache ( 35 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " resprate_apache "
# " h1_pao2fio2ratio_min " and " resprate_apache " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and resprate_apache
# MI = 0.02059505567205555
# MI: 0.02059505567205555
# Elapsed time: 0:00:00.496259
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) icu_admit_source ( 8 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " icu_admit_source "
# " h1_pao2fio2ratio_min " and " icu_admit_source " are data pair type DC
# Calculating discrete-continious MI for h1_pao2fio2ratio_min and icu_admit_source
# Discrete: icu_admit_source Continuous: h1_pao2fio2ratio_min
# responses = ['Operating Room / Recovery', 'Accident & Emergency', 'Floor', 'Other ICU', 'Other Hospital']
# pmi list = [0.0, 0.0, 0.005165947751877953, 0.00038126564686713493, 0.0]
# MI: 0.0009159206119532699
# MI: 0.0009159206119532699
# Elapsed time: 0:00:00.401678
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) icu_stay_type ( 9 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " icu_stay_type "
# " h1_pao2fio2ratio_min " and " icu_stay_type " are data pair type DC
# Calculating discrete-continious MI for h1_pao2fio2ratio_min and icu_stay_type
# Discrete: icu_stay_type Continuous: h1_pao2fio2ratio_min
# responses = ['admit', 'transfer', 'readmit']
# pmi list = [0.0, 0.004463500348845573, 0.0]
# MI: 0.00021062702449371678
# MI: 0.00021062702449371678
# Elapsed time: 0:00:01.683945
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) icu_type ( 10 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " icu_type "
# " h1_pao2fio2ratio_min " and " icu_type " are data pair type DC
# Calculating discrete-continious MI for h1_pao2fio2ratio_min and icu_type
# Discrete: icu_type Continuous: h1_pao2fio2ratio_min
# responses = ['Med-Surg ICU', 'MICU', 'SICU', 'CSICU', 'Cardiac ICU', 'CCU-CTICU', 'Neuro ICU', 'CTICU']
# pmi list = [0.0, 0.00953465860995295, 0.0059764439471374775, 0.0016888576146296685, 0.0004162726008216655, 0.0, 0.010726145907285378, 0.0]
# MI: 0.0022504712599448144
# MI: 0.0022504712599448144
# Elapsed time: 0:00:00.397059
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) pre_icu_los_days ( 11 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " pre_icu_los_days "
# " h1_pao2fio2ratio_min " and " pre_icu_los_days " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and pre_icu_los_days
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.547308
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) weight ( 12 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " weight "
# " h1_pao2fio2ratio_min " and " weight " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and weight
# MI = 0
# MI: 0
# Elapsed time: 0:00:00.501036
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) albumin_apache ( 13 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " albumin_apache "
# " h1_pao2fio2ratio_min " and " albumin_apache " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and albumin_apache
# MI = 1.0367481176002573
# MI: 1.0367481176002573
# Elapsed time: 0:00:00.546167
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) apache_2_diagnosis ( 14 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " apache_2_diagnosis "
# " h1_pao2fio2ratio_min " and " apache_2_diagnosis " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and apache_2_diagnosis
# MI = 0.0013203932527936502
# MI: 0.0013203932527936502
# Elapsed time: 0:00:00.544257
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) apache_3j_diagnosis ( 15 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " apache_3j_diagnosis "
# " h1_pao2fio2ratio_min " and " apache_3j_diagnosis " are data pair type CC
# Calculating mutual information for h1_pao2fio2ratio_min and apache_3j_diagnosis
# MI = 0.009039152528972139
# MI: 0.009039152528972139
# Elapsed time: 0:00:00.596316
# Calculating mutual information for h1_pao2fio2ratio_min ( 168 of 180 ) apache_post_operative ( 16 of 180 )
# Finding pair type for " h1_pao2fio2ratio_min " and " apache_post_operative "
# " h1_pao2fio2ratio_min " and " apache_post_operative " are data pair type DC
# Calculating discrete-continious MI for h1_pao2fio2ratio_min and apache_post_operative
# Discrete: apache_post_operative Continuous: h1_pao2fio2ratio_min
# responses = ['1', '0']
# pmi list = [0, 0]
# MI: 0.0

# %%
stack.to_csv(cd+'results.csv',index=False)

# %% [markdown]
# # Network Graphing

# %%
# Re-import the Mutual Information results
# (this is helpful if you want to re-generate visualizations
# without having to re-run the mutual information calculations)
stack = pd.read_csv(cd+'results.csv')

# %%
# Sort our values and (optionally) exclude Mutual Infomation scores above 1 (which are often proxies for one another)
sorted_stack = stack.sort_values(by='v',ascending=False)
#sorted_stack = sorted_stack[sorted_stack['v']<1]

# %% [markdown]
# ## Thresholding

# %%
# Create a data frame of edge counts and number of components for a given threshold
e = pd.DataFrame(columns=['mi_threshold','edge_count','components'])

# %%
# Fill in the 'e' data frame with the number of edges and number of components across a range of thresholds
for i in np.arange(np.round(sorted_stack['v'].min(),2), np.round(sorted_stack['v'].max(),2), 0.01):
    
    s = sorted_stack[sorted_stack['v']>i]
    
    G = nx.Graph()
    G.add_nodes_from(list(dict.fromkeys((list(s['x'].unique())+list(s['y'].unique())))))
    G.add_edges_from(list(zip(s['x'],s['y'])))
    
    e = e.append({'mi_threshold': i, 'edge_count': (sorted_stack['v']>i).sum(), 'components':nx.number_connected_components(G)},ignore_index=True)

# %%
# Plot the number of edges for a range of mutual information scores
sns.lineplot(e['mi_threshold'],e['edge_count'])

# %%
# Plot the number of components for a range of mutual information scores
sns.lineplot(e['mi_threshold'],e['components'])

# %%
# Find the mutual information threshold which maximizes the component count
max_component_threshold = e[e['components']==max(e['components'])].max()['mi_threshold']
# optional: if there are multiple MI thresholds which maximize the number of components,
# you may want to experiment with thresholding at .min()['mi_threshold'] instead of .max()['mi_threshold']
# depending on your application; we have selected the maximum threshold for maximizing component counts,
# as this minimizes the edge count over the minimum threshold, which reduces the visualization exploration space,
# while still maximizing component counts

# %%
# Threshold the edge list by the mutual information threshold which maximizes the component count
thresh_stack = sorted_stack[sorted_stack['v']>max_component_threshold]
thresh_stack = thresh_stack.rename(columns={'x':'src','y':'target','v':'weight'})
thresh_stack['viztype']=[calc_pairtype(x,y) for x,y in zip(thresh_stack['src'],thresh_stack['target'])]
thresh_stack

# %% [markdown]
# ## Node and Edge Lists

# %%
# Create a networkx graph from the list of pairs
G=nx.from_pandas_edgelist(thresh_stack, 'src', 'target', ['weight'])

# %%
nodelist = {}
for n in list(dict.fromkeys((list(s['x'].unique())+list(s['y'].unique())))):
    nodelist[n]={'type':'continuous' if (response_list['class'][n])=='c' else 'discrete','neighbors':dict(G[n])}

# %%
json_out = {}
json_out['edges']=(thresh_stack).to_dict(orient='records')
json_out['nodes']=nodelist

# %%
with open(str(cd+'output/graph.json'), 'w') as json_file:
  json.dump(json_out, json_file)

# %%
chart=True

for i,row in thresh_stack.iterrows():
    viz(row['src'],row['target'])

# %% [markdown]
# ## Positioning

# %%
def calculate_positions(thresh_stack):

  # Generate position data for each node:
  #pos=layout(G)
  # if weighted:
  pos=nx.kamada_kawai_layout(G, weight='weight')
      
  # Save x, y locations of each edge
  edge_x = []
  edge_y = []

  # Calculate x,y positions of an edge's 'start' (x0,y0) and 'end' (x1,y1) points
  for edge in G.edges():
      x0, y0 = pos[edge[0]]
      x1, y1 = pos[edge[1]]
      edge_x.append(x0)
      edge_x.append(x1)
      edge_y.append(y0)
      edge_y.append(y1)

  # Bundle it all up in a dict:
  edges = dict(x=edge_x,y=edge_y)

  # Save x, y locations of each node
  node_x = []
  node_y = []

  # Save node stats for annotation
  node_name = []
  node_adjacencies = []
  node_centralities = []

  # Calculate x,y positions of nodes
  for node in G.nodes():
      node_name.append(node)# Save node names
      x, y = pos[node]
      node_x.append(x)
      node_y.append(y)

  for node, adjacencies in enumerate(G.adjacency()):
      node_adjacencies.append(len(adjacencies[1]))

  for n in G.nodes():
      node_centralities.append(nx.degree_centrality(G)[n])

  # Bundle it all up in a dict:
  nodes = dict(x=node_x,y=node_y,name=node_name,adjacencies=node_adjacencies,centralities=node_centralities)

  return edges,nodes

# %%
[edges,nodes] = calculate_positions(thresh_stack)

# %% [markdown]
# ## Draw Graph

# %%
def draw_graph(edges,nodes,title,**kwargs):

  # Draw edges
  edge_trace = go.Scatter(
      x=edges['x'], y=edges['y'],
      line=dict(width=0.5, color='#888'),
      mode='lines+markers',
      hoverinfo='text')

  # Draw nodes
  node_trace = go.Scatter(
      x=nodes['x'],
      y=nodes['y'],
      # Optional: Add labels to points *without* hovering (can get a little messy)
      mode='markers+text',
      # ...or, just add markers (no text)
      #mode='markers',
      text=nodes['name'],
      hoverinfo='text')
  filename=title.lower().replace(" ","_")

  # Color the node by its number of connections
  #node_trace.marker.color = nodes['adjacencies']
  node_trace.marker.color = nodes['centralities']
  
  # Draw figure
  fig = go.Figure(data=[edge_trace,node_trace],
            layout=go.Layout(
              title=title,
              titlefont_size=16,
              showlegend=False,
              hovermode='closest',
              margin=dict(b=20,l=5,r=5,t=120),
              xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
              yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
              template='plotly_white')
              )
  
  fig.update_traces(textposition='top center')
  # Show figure
  fig.show()

# %%
draw_graph(edges,nodes,'Example Graph')
